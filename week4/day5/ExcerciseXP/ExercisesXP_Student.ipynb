# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# **Problem Statement:** The objective is to predict the posibilty of borrower to default on a loan. These predictions will support lending decisions such as whether to approve a loan or not, what the interest rate to offer, how much to lend, and which borrowers require closer monitoring after disbursement.
#
# **Data Types Needed:**
#
# I will investigate the financial stability. I will collect personal and demographic details such as age, marital status, number of dependents, education level, employment type and residential stability.
#
# Also I will investigate the documents about income and employment data such as monthly income, employer type, job title, length of employment. It is important because borrowers with stable and sufficient income are generally more likely to repay loans on time.
#
# Additionaly I will collect credit scores, credit history, repayment discipline and other bank information such as deposits, number of accounts, overdraft frequency and etc. This is the strongest indicators of future default risk.
#
# I will collect behavioral or digital interaction data such as frequency of logins to the lender portal, response speed to reminders, contactability, and changes in contact details. These variables may be useful because disengagement or unstable contact patterns can sometimes be early warning signs.
#
# **Data sources and Collection plan:**
#
# The main source is internal bank information about personnel accounts and cash movements, loan terms, payment schedules and final loan outcomes.
#
# A second key source is customer  documents about applicant demographics, identity information, declared income, employment details and verified documents.
#
# A third source is the credit bureaus. I will integrate credit bureaus data through secure APIs, batch files, or regular reporting feeds to obtain credit scores, delinquency records, outstanding debts and other external credit obligations.
#
# A fourth source is collectors and servicing systems. From these systems, I would gather information on reminders, restructuring events, collectors actions and results.
#
# A fifth source - external economic or geographic data such as local unemployment rates, inflation, regional risk indicators, or sector conditions.
#
# All these datasets should be cleaned, standardized, matched through common identifiers and loaded into a secure analytical environment before feature engineering and model training.
#
# This project involves several risks and constraints including privacy and regulatory compliance when handling sensitive financial and personal data. Data quality issues such as missing income values, inconsistent credit histories, and labeling errors may reduce model accuracy. Governance is also important because credit models must be explainable, monitored for fairness, and regularly validated to ensure responsible use in lending decisions.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features = [
    "employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","term"
]

print("You will now justify the selected features in complete sentences below:")
# Out:
# You will now justify the selected features in complete sentences below:

# %% [markdown]
# **INCLUDE:**
#
# **Credit_score** is one of the strongest predictors of default because it summarizes the past repayment behavior and credit risk profile. Lower credit scores typically indicate a higher probability of missed payments and default.
#
# **Debt_to_income** measures how much of the borrower’s income is already committed to debt obligations. A higher debt-to-income ratio indicates that the borrower has less financial flexibility and is therefore more likely to default.
#
# **Annual_income** reflects the repayment capacity. Borrowers with lower income relative to loan obligations may struggle to meet payments, increasing default risk.
#
# **Loan_amount** is important because larger loans increase the financial burden on the borrower. Higher loan amounts typically lead to higher monthly payments and therefore higher default probability.
#
# **Interest_rate** directly affects the cost of borrowing and monthly payments. Higher interest rates increase repayment burden and are often associated with higher-risk borrowers.
#
# **Employment_length** indicates job stability. Borrowers with longer employment histories tend to have more stable income and are generally less likely to default.
#
# **Num_delinquencies** captures the  history of missed or late payments. A higher number of delinquencies is a strong signal of future repayment problems.
#
# **Total_utilization** measures how much of available credit the borrower is using. High utilization suggests financial stress and limited remaining credit capacity, which increases default risk.
#
# **Num_open_accounts** provides information about the credit exposure and behavior. A very high number of accounts may indicate overextension, while a very low number may indicate limited credit history.
#
# **Term** is relevant because longer loan terms increase uncertainty and exposure to future financial changes.
#
# **EXCLUDE:**
#
# **Age** is often indirect compared to financial variables.
#
# **State** is excluded because geographic location may introduce fairness issues and may not generalize well across regions.
#
# **Zip_code** is often indirect compared to financial variables too.
#
# **Application_type** is excluded because individual vs. joint applications may add limited predictive value compared to stronger financial features.
#
# **Purpose** is excluded because loan purpose is often noisy and inconsistently labeled.
#
# **Home_ownership** is excluded because its predictive value is usually weaker than direct financial indicators.
#
# Categorical variables such as home_ownership, purpose, and term would be encoded using one-hot encoding, while high-cardinality variables would be encoded using target encoding if necessary.
# Missing values in numerical features would be imputed using median imputation, and categorical missing values would be filled with a separate “Unknown” category to preserve information.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0
#
# Confusion matrix:
#  [[6 0]
#  [0 4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# ### Your answer
# > To-Do: Please write complete sentences that explain your model choice, your evaluation plan, your approach to class imbalance, and your threshold selection strategy.
#
# I prefer to use Logistic regression for loan default prediction. Logistic regression is suitable because it is interpretable, stable, and commonly used in credit risk modeling where regulatory explainability is important.
#
# I will split the data into training and test sets(using 80/20 split), while ensuring stratification by the target variable to preserve the default rate.
# I will report ROC-AUC as a primary ranking metric because it measures how well the model separates defaulters from non-defaulters across all thresholds.
#
# I will also report Precision, Recall, and F1-score, since in loan default prediction it is important to balance detecting risky borrowers with minimizing false positives.
#
# I will choose the decision threshold based on business objectives, such as minimizing expected loss or achieving a target recall for defaulters. For example, if missing a default is costly, I will lower the threshold to increase recall even at the cost of more false positives.
#
# I will use stratified splitting to preserve class proportions in both training and test sets. I would also apply class weights in models to penalize misclassification of defaulters more heavily.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# **Predicting Stock Prices**
#
# The most suitable machine learning paradigm for predicting stock prices is **supervised learning**, because historical data with known outcomes is available.
# The input data would include historical stock prices, trading volume, technical indicators, and possibly macroeconomic variables over time.
# The output would be the predicted future stock price or price movement for a specified time horizon.
# The learning signal or objective would be to minimize the difference between predicted prices and actual future prices, using a loss function such as mean squared error.
#
# **Organizing a Library of Books**
#
# The most suitable machine learning paradigm for organizing a library of books is **unsupervised learning**, specifically clustering, because books can be grouped based on similarities without predefined labels.
# The input data would include book metadata such as titles, descriptions, keywords, authors, and possibly text embeddings derived from book content.
# The output would be clusters of books representing groups with similar themes or genres.
#
# **Program a Robot to Navigate a Maze**
#
# The most suitable machine learning paradigm for programming a robot to navigate a maze is **reinforcement learning**, because the robot learns through interaction with an environment.
# The input data would include the robot’s current state such as position, available actions, and information about the surrounding environment.
# The output would be the action the robot should take, such as move forward, turn left, or turn right.
# The learning signal or objective would be to maximize cumulative reward, such as reaching the goal quickly while minimizing collisions or unnecessary steps.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# **Supervised Learning Model (Classification)**
# For a supervised learning model such as logistic regression, I will evaluate performance using a stratified train-test split combined with stratified k-fold cross-validation on the training data.
# I will report metrics including accuracy, precision, recall, F1-score, ROC-AUC, and PR-AUC to capture both overall performance and class-specific behavior.
# I will also analyze the confusion matrix to understand the trade-offs between false positives and false negatives. The decision threshold would be selected based on business objectives, such as maximizing recall or minimizing expected cost.
# A key evaluation challenge for supervised learning is that strong performance on historical data may not generalize well if the data distribution changes over time.
#
# **Unsupervised Learning Model (Clustering)**
# For an unsupervised learning model such as K-means clustering, I will evaluate cluster quality using the silhouette score to measure separation and cohesion of clusters.
# I will also apply the elbow method by plotting within-cluster sum of squares against the number of clusters to identify an appropriate cluster count.
# A key evaluation challenge for unsupervised learning is the absence of ground-truth labels, which makes it difficult to objectively determine whether clusters are meaningful.
#
# **Reinforcement Learning Model**
# For a reinforcement learning model, I will measure performance by tracking cumulative reward over episodes and monitoring whether it increases and stabilizes during training.
# I will evaluate convergence by plotting reward curves and checking whether performance plateaus as the policy improves.
# I will also assess exploration versus exploitation balance by monitoring exploration parameters such as epsilon decay and ensuring the agent continues to explore sufficiently before converging.
# Additional evaluation would include measuring success rate, average steps to goal, and failure rate across multiple runs.
# Key evaluation challenge for reinforcement learning is that performance can be highly variable and sensitive to randomness, making reproducible evaluation difficult.
